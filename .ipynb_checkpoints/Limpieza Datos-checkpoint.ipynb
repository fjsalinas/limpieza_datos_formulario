# %%
import pandas as pd
import re
import string
from sklearn.feature_extraction.text import CountVectorizer
import nltk
from nltk.corpus import stopwords

# %%
data = pd.read_pickle('data.pkl')
data.head()
# Out:
#           rut      telefono                  email  \
# 0  75734387-7  +56908214818    efdidejdf@gmail.com
# 1  60822169-9  +56945333340  aclghkffe@hotmail.com
# 2  40250240-9  +56908065879    eaifhdblf@gmail.com
# 3  94133101-k  +56992778488  fcaigkchi@hotmail.com
# 4  94668911-8  +56980640791    chfhaiffg@gmail.com
#
#                                    producto  \
# 0                        Crédito de Consumo
# 1                        Crédito de Consumo
# 2                       Crédito Hipotecario
# 3  Crédito de Consumo y Crédito Hipotecario
# 4                        Crédito de Consumo
#
#                                           comentario
# 0  uluagaCamila arlosruizma Qué pasa en los casos...
# 1  BVA_Colombia Señores BVA_Colombia solicite el ...
# 2  hechy2780 Si 😥 peor cn el tema de las escuelas...
# 3  Fuga masiva a otros bancos de antanderchile he...
# 4  La pandemia de coronavirus, que ha dejado hast...

# %%
def clean_text_round1(text):
    #Make text lowercase 
    text = text.lower()
    # remove punctuation
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    #remove words containing numbers.
    text = re.sub('\w*\d\w*', '', text)
    
    
    return text

round1 = lambda x: clean_text_round1(x)

# %%
data_clean = pd.DataFrame(data.comentario.apply(round1))
data_clean
# Out:
#                                            comentario
# 0   uluagacamila arlosruizma qué pasa en los casos...
# 1   bvacolombia señores bvacolombia solicite el be...
# 2    si 😥 peor cn el tema de las escuelas si no tr...
# 3   fuga masiva a otros bancos de antanderchile he...
# 4   la pandemia de coronavirus que ha dejado hasta...
# ..                                                ...
# 81   este día he hecho el pago de un crédito hipot...
# 82  onyrodriguezof ancolombia hola moni yo tengo  ...
# 83  hola bvaperu mi deuda es con el bbva consumer ...
# 84  la cev pide aplazar impuestos y liquidez para ...
# 85  postergarán el pago del inmobiliario urbano en...
#
# [86 rows x 1 columns]

# %%
def clean_text_round2(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

round2 = lambda x: clean_text_round2(x)

# %%
data_clean = pd.DataFrame(data_clean.comentario.apply(round2))
data_clean
# Out:
#                                            comentario
# 0   uluagacamila arlosruizma qué pasa en los casos...
# 1   bvacolombia señores bvacolombia solicite el be...
# 2    si 😥 peor cn el tema de las escuelas si no tr...
# 3   fuga masiva a otros bancos de antanderchile he...
# 4   la pandemia de coronavirus que ha dejado hasta...
# ..                                                ...
# 81   este día he hecho el pago de un crédito hipot...
# 82  onyrodriguezof ancolombia hola moni yo tengo  ...
# 83  hola bvaperu mi deuda es con el bbva consumer ...
# 84  la cev pide aplazar impuestos y liquidez para ...
# 85  postergarán el pago del inmobiliario urbano en...
#
# [86 rows x 1 columns]

# %%
#stopwords_kaggle = pd.read_csv("../spanishST.txt", encoding = "latin-1", header = None, names = ['stopwords'])['stopwords'].tolist()
cv = CountVectorizer(stop_words=stopwords.words('spanish'))
data_cv = cv.fit_transform(data_clean.comentario)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
data_dtm.index = data_clean.index
data_dtm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-7469c79b7409> in <module>
#       1 #stopwords_kaggle = pd.read_csv("../spanishST.txt", encoding = "latin-1", header = None, names = ['stopwords'])['stopwords'].tolist()
# ----> 2 cv = CountVectorizer(stop_words=stopwords.words('spanish'))
#       3 data_cv = cv.fit_transform(data_clean.comentario)
#       4 data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names())
#       5 data_dtm.index = data_clean.index
#
# NameError: name 'stopwords' is not defined

# %%
stopwords
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-380d00e3194f> in <module>
# ----> 1 stopwords
#
# NameError: name 'stopwords' is not defined
